# %% [markdown]
# # Exploration notebook
#
# This notebook is a **starting point** for exploring the lexical simplification
# datasets:
#
# - `En-Dataset.csv`
# - `Fr-Dataset.csv`
#
# You are encouraged to extend this notebook or create new ones, but your main
# pipelines can also live in `src/`.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from pathlib import Path

DATA_DIR = Path("data")

# %%
en_path = DATA_DIR / "En-Dataset.csv"
fr_path = DATA_DIR / "Fr-Dataset.csv"

en = pd.read_csv(en_path)
fr = pd.read_csv(fr_path)

en.head(), fr.head()

# %% [markdown]
# ## Task 0 – further data overview (your space)
#
# Use this section to run any additional analyses that help you understand the data
# (e.g. sampling sentences, checking noise, looking at length vs label, etc.).

# %% [markdown]
# ## Task 1 – Estimating the *true* proportion of simplified sentences
#
# You may prototype your ideas here before moving them into `src/02_estimate_simplified_proportion.py`.

# %% [markdown]
# ## Task 2 – Parallel corpus alignment
#
# You can sketch alignment ideas or small experiments here.

# %% [markdown]
# ## Task 3 – Free analysis
#
# Classifier / complexity scoring / lexical patterns – feel free to use this
# notebook as a sandbox.
